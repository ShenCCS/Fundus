# %%
# conda env : retfound

import torch
import models_vit
import torch.nn as nn
import torch.optim as optim
import torchvision
import matplotlib.pyplot as plt

from pathlib import  Path
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
from util.pos_embed import interpolate_pos_embed
from timm.models.layers import trunc_normal_
from torch.nn import Linear,ReLU,CrossEntropyLoss

# %%
# call the model
model_R = models_vit.__dict__['vit_large_patch16'](
    num_classes=2,
    drop_path_rate=0.2,
    global_pool=True,
)

# load RETFound weights
checkpoint = torch.load('RETFound_cfp_weights.pth', map_location='cpu')
checkpoint_model = checkpoint['model']
state_dict = model_R.state_dict()

for k in ['head.weight', 'head.bias']:
    if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
        print(f"Removing key {k} from pretrained checkpoint")
        del checkpoint_model[k]

# interpolate position embedding
interpolate_pos_embed(model_R, checkpoint_model)

# load pre-trained model
msg = model_R.load_state_dict(checkpoint_model, strict=False)

assert set(msg.missing_keys) == {'head.weight', 'head.bias', 'fc_norm.weight', 'fc_norm.bias'}

# manually initialize fc layer
trunc_normal_(model_R.head.weight, std=2e-5)

#print("Model = %s" % str(model_R))
# Out:
# Parameter containing:
# tensor([[-1.5079e-05, -3.9504e-06, -1.1748e-05,  ...,  1.9249e-05,
#           3.7390e-05,  2.4874e-06],
#         [ 2.8086e-05,  2.7409e-05, -1.1004e-05,  ...,  1.9741e-06,
#           5.2159e-05,  5.3064e-06]], requires_grad=True)

# %%
data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/HTN/', transform=data_transform)

total_data = len(train_data)  #624
split = int(0.8 * total_data)     #499

# %%
split
# Out:
# 499

# %%
training_data, validation_data = torch.utils.data.random_split(train_data,[split,total_data - split])

# %%
train_loader = torch.utils.data.DataLoader(training_data, batch_size=32, shuffle=True)
val_loader = torch.utils.data.DataLoader(validation_data, batch_size=32, shuffle=True)


criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


num_epochs = 50
training_loss = []  
validation_loss = []
train_acc = []
validatoin_acc = []

#Training

for epoch in range(num_epochs):
    model_R.train()
    running_train_loss = 0.0
    train_correct = 0
    train_total = 0

    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        optimizer.zero_grad()
        outputs = model_R(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_train_loss += loss.item()

        _, predicted = torch.max(outputs, 1)
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

    train_loss = running_train_loss / len(train_loader)
    train_accuary = train_correct / train_total
    training_loss.append(train_loss)
    train_acc.append(train_accuary)


#Validation

    model_R.eval()
    running_val_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for i,data in enumerate(val_loader,0):
            inputs,labels = data
            outputs = model_R(inputs)
            val_loss = criterion(outputs,labels)
            running_val_loss += val_loss.item()

            _,predicted = torch.max(outputs,1)
            val_total += labels.size(0)
            val_correct += (predicted == labels).sum().item()


    val_loss = running_val_loss / len(val_loader)
    val_accuracy = val_correct / val_total
    validation_loss.append(val_loss)
    validatoin_acc.append(val_accuracy)
    

    print(f"Epoch {epoch+1}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_accuary*100:.2f}%, Validatoin Loss: {val_loss:.4f}, Validatoin Accuracy: {val_accuracy*100:.2f}%")


plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), training_loss,label = 'Training')
plt.plot(range(1, num_epochs + 1), validation_loss,label = 'Validatoin')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_acc,color='g',label = 'Training')
plt.plot(range(1, num_epochs + 1), validatoin_acc,color='r',label = 'Validation')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1, Training Loss: 0.6706, Training Accuracy: 60.12%, Validatoin Loss: 0.6304, Validatoin Accuracy: 68.00%
# Epoch 2, Training Loss: 0.6745, Training Accuracy: 61.72%, Validatoin Loss: 0.6043, Validatoin Accuracy: 68.00%
# Epoch 3, Training Loss: 0.6765, Training Accuracy: 59.72%, Validatoin Loss: 0.5988, Validatoin Accuracy: 70.40%
# Epoch 4, Training Loss: 0.6511, Training Accuracy: 64.53%, Validatoin Loss: 0.5854, Validatoin Accuracy: 72.80%
# Epoch 5, Training Loss: 0.6826, Training Accuracy: 62.12%, Validatoin Loss: 0.8703, Validatoin Accuracy: 32.80%
# Epoch 6, Training Loss: 0.7475, Training Accuracy: 58.32%, Validatoin Loss: 0.7065, Validatoin Accuracy: 68.00%
# Epoch 7, Training Loss: 0.6653, Training Accuracy: 60.92%, Validatoin Loss: 0.6201, Validatoin Accuracy: 66.40%
# Epoch 8, Training Loss: 0.6501, Training Accuracy: 65.53%, Validatoin Loss: 0.5664, Validatoin Accuracy: 76.00%
# Epoch 9, Training Loss: 0.6075, Training Accuracy: 67.13%, Validatoin Loss: 0.5655, Validatoin Accuracy: 73.60%
# Epoch 10, Training Loss: 0.5972, Training Accuracy: 68.14%, Validatoin Loss: 0.5296, Validatoin Accuracy: 77.60%
# Epoch 11, Training Loss: 0.5885, Training Accuracy: 68.74%, Validatoin Loss: 0.5234, Validatoin Accuracy: 78.40%
# Epoch 12, Training Loss: 0.5797, Training Accuracy: 69.74%, Validatoin Loss: 0.5233, Validatoin Accuracy: 77.60%
# Epoch 13, Training Loss: 0.6031, Training Accuracy: 69.54%, Validatoin Loss: 0.5239, Validatoin Accuracy: 77.60%
# Epoch 14, Training Loss: 0.6249, Training Accuracy: 66.93%, Validatoin Loss: 0.6233, Validatoin Accuracy: 64.80%
# Epoch 15, Training Loss: 0.6284, Training Accuracy: 67.33%, Validatoin Loss: 0.5525, Validatoin Accuracy: 71.20%
# Epoch 16, Training Loss: 0.6019, Training Accuracy: 65.93%, Validatoin Loss: 0.5813, Validatoin Accuracy: 69.60%
# Epoch 17, Training Loss: 0.5811, Training Accuracy: 67.74%, Validatoin Loss: 0.4951, Validatoin Accuracy: 79.20%
# Epoch 18, Training Loss: 0.5812, Training Accuracy: 71.94%, Validatoin Loss: 0.4879, Validatoin Accuracy: 78.40%
# Epoch 19, Training Loss: 0.5552, Training Accuracy: 71.54%, Validatoin Loss: 0.4832, Validatoin Accuracy: 80.80%
# Epoch 20, Training Loss: 0.5420, Training Accuracy: 73.15%, Validatoin Loss: 0.4815, Validatoin Accuracy: 77.60%
# Epoch 21, Training Loss: 0.5444, Training Accuracy: 73.35%, Validatoin Loss: 0.4972, Validatoin Accuracy: 80.80%
# Epoch 22, Training Loss: 0.5275, Training Accuracy: 74.35%, Validatoin Loss: 0.5121, Validatoin Accuracy: 77.60%
# Epoch 23, Training Loss: 0.5892, Training Accuracy: 69.94%, Validatoin Loss: 0.4856, Validatoin Accuracy: 77.60%
# Epoch 24, Training Loss: 0.5355, Training Accuracy: 72.95%, Validatoin Loss: 0.4617, Validatoin Accuracy: 78.40%
# Epoch 25, Training Loss: 0.5049, Training Accuracy: 74.75%, Validatoin Loss: 0.4396, Validatoin Accuracy: 80.00%
# Epoch 26, Training Loss: 0.5113, Training Accuracy: 75.35%, Validatoin Loss: 0.4263, Validatoin Accuracy: 80.00%
# Epoch 27, Training Loss: 0.4827, Training Accuracy: 77.56%, Validatoin Loss: 0.4620, Validatoin Accuracy: 80.80%
# Epoch 28, Training Loss: 0.4742, Training Accuracy: 77.76%, Validatoin Loss: 0.4824, Validatoin Accuracy: 80.00%
# Epoch 29, Training Loss: 0.5005, Training Accuracy: 76.35%, Validatoin Loss: 0.4189, Validatoin Accuracy: 83.20%
# Epoch 30, Training Loss: 0.4295, Training Accuracy: 82.57%, Validatoin Loss: 0.3899, Validatoin Accuracy: 83.20%
# Epoch 31, Training Loss: 0.4465, Training Accuracy: 78.16%, Validatoin Loss: 0.4360, Validatoin Accuracy: 76.80%
# Epoch 32, Training Loss: 0.3911, Training Accuracy: 82.36%, Validatoin Loss: 0.3905, Validatoin Accuracy: 82.40%
# Epoch 33, Training Loss: 0.4326, Training Accuracy: 79.56%, Validatoin Loss: 0.3626, Validatoin Accuracy: 85.60%
# Epoch 34, Training Loss: 0.3750, Training Accuracy: 85.97%, Validatoin Loss: 0.3548, Validatoin Accuracy: 85.60%
# Epoch 35, Training Loss: 0.3734, Training Accuracy: 85.17%, Validatoin Loss: 0.3854, Validatoin Accuracy: 84.00%
# Epoch 36, Training Loss: 0.4126, Training Accuracy: 79.56%, Validatoin Loss: 0.3872, Validatoin Accuracy: 83.20%
# Epoch 37, Training Loss: 0.3861, Training Accuracy: 81.76%, Validatoin Loss: 0.3767, Validatoin Accuracy: 86.40%
# Epoch 38, Training Loss: 0.3788, Training Accuracy: 83.77%, Validatoin Loss: 0.3450, Validatoin Accuracy: 86.40%
# Epoch 39, Training Loss: 0.3596, Training Accuracy: 84.57%, Validatoin Loss: 0.3628, Validatoin Accuracy: 84.00%
# Epoch 40, Training Loss: 0.3339, Training Accuracy: 84.17%, Validatoin Loss: 0.3031, Validatoin Accuracy: 86.40%
# Epoch 41, Training Loss: 0.3009, Training Accuracy: 88.78%, Validatoin Loss: 0.3006, Validatoin Accuracy: 88.00%
# Epoch 42, Training Loss: 0.2618, Training Accuracy: 89.58%, Validatoin Loss: 0.2982, Validatoin Accuracy: 84.80%
# Epoch 43, Training Loss: 0.2804, Training Accuracy: 89.18%, Validatoin Loss: 0.3819, Validatoin Accuracy: 83.20%
# Epoch 44, Training Loss: 0.2990, Training Accuracy: 88.18%, Validatoin Loss: 0.2906, Validatoin Accuracy: 85.60%
# Epoch 45, Training Loss: 0.2456, Training Accuracy: 90.78%, Validatoin Loss: 0.2713, Validatoin Accuracy: 85.60%
# Epoch 46, Training Loss: 0.2661, Training Accuracy: 88.38%, Validatoin Loss: 0.2936, Validatoin Accuracy: 88.00%
# Epoch 47, Training Loss: 0.2495, Training Accuracy: 88.98%, Validatoin Loss: 0.2659, Validatoin Accuracy: 88.80%
# Epoch 48, Training Loss: 0.1933, Training Accuracy: 92.38%, Validatoin Loss: 0.2214, Validatoin Accuracy: 89.60%
# Epoch 49, Training Loss: 0.1605, Training Accuracy: 93.19%, Validatoin Loss: 0.2965, Validatoin Accuracy: 88.80%
# Epoch 50, Training Loss: 0.1568, Training Accuracy: 93.99%, Validatoin Loss: 0.2366, Validatoin Accuracy: 92.00%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from sklearn.metrics import roc_curve, roc_auc_score, auc
import matplotlib.pyplot as plt

# %%
model_R.eval()
all_labels = []  # 存储所有验证集的真实标签
all_scores = []  # 存储所有验证集的模型输出概率分数

with torch.no_grad():
    for i, data in enumerate(val_loader, 0):
        inputs, labels = data
        outputs = model_R(inputs)

        all_labels.extend(labels.cpu().numpy())  # 将真实标签添加到列表
        all_scores.extend(outputs[:, 1].cpu().numpy())  # 将模型输出的概率分数添加到列表

# 5. 计算 ROC 曲线和 AUROC
fpr, tpr, thresholds = roc_curve(all_labels, all_scores)
auroc = auc(fpr, tpr)

print(f"AUROC: {auroc:.4f}")

# 6. 绘制 ROC 曲线
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUROC = {auroc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()
# Out:
# AUROC: 0.9647

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# model_R.to(device)
# data_transform = transforms.Compose([transforms.Resize((224, 224)),transforms.ToTensor()])
# train_data = datasets.ImageFolder('/home/john/network/RETFound/RETFound_MAE-main/data/', transform=data_transform)
# train_loader = torch.utils.data.DataLoader(train_data, batch_size=32, shuffle=True)


# criterion = nn.CrossEntropyLoss()
# criterion = criterion.to(device)
# optimizer = optim.SGD(model_R.parameters(), lr=0.001, momentum=0.9)


# num_epochs = 200
# losses = []  
# accuracies = []  

# for epoch in range(num_epochs):
#     running_loss = 0.0
#     correct = 0
#     total = 0

#     for i, data in enumerate(train_loader, 0):
#         inputs, labels = data
#         inputs, labels = inputs.to(device), labels.to(device)
#         optimizer.zero_grad()
#         outputs = model_R(inputs)
#         loss = criterion(outputs, labels)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item()

#         _, predicted = torch.max(outputs, 1)
#         total += labels.size(0)
#         correct += (predicted == labels).sum().item()

#     epoch_loss = running_loss / len(train_loader)
#     epoch_accuracy = correct / total
#     losses.append(epoch_loss)
#     accuracies.append(epoch_accuracy)

#     print(f"Epoch {epoch+1}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy*100:.2f}%")


# plt.figure(figsize=(10, 4))
# plt.subplot(1, 2, 1)
# plt.plot(range(1, num_epochs + 1), losses, marker='o')
# plt.title('Training Loss')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')

# plt.subplot(1, 2, 2)
# plt.plot(range(1, num_epochs + 1), accuracies, marker='o', color='g')
# plt.title('Training Accuracy')
# plt.xlabel('Epoch')
# plt.ylabel('Accuracy')

# plt.tight_layout()
# plt.show()
